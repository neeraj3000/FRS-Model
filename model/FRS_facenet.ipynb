# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from mtcnn.mtcnn import MTCNN
from keras_facenet import FaceNet

# %%
import os
import cv2 as cv

# %%
directory = 'C:\\Users\\Satheesh\\Documents\\FRS\\celeb'
labels = []
faces = []

# %%
for celeb in os.listdir(directory):
    path = os.path.join(directory,celeb)
    for img_file in os.listdir(path):
        img_path = os.path.join(path,img_file)
        img = cv.imread(img_path)
        img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
        img = cv.resize(img,(160,160))
        faces.append(img)
        labels.append(celeb)

# %%
print(len(labels))
print(len(faces))
# Out:
# 1489
# 1489

# %%
embedder = FaceNet()

def get_embeddings(face_img):
    face_img = face_img.astype('float32')
    face_img = np.expand_dims(face_img,axis=0)
    y_hat = embedder.embeddings(face_img)
    return y_hat[0]
# Out:
# WARNING:tensorflow:From C:\Users\Satheesh\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %%
Embeddings = []
for img in faces:
    Embeddings.append(get_embeddings(img))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 15s 15s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# ...

# %%
print(len(Embeddings))

# %%
Embeddings = np.asarray(Embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Embeddings = np.asarray(Embeddings)
#
# NameError: name 'Embeddings' is not defined

# %%
print(Embeddings.shape)

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear',probability=True)

# %%
np.savez_compressed('face_embeddings.npz',Embeddings,labels)

# %%
data = np.load('face_embeddings.npz')

Embeddings = data['arr_0']  
labels = data['arr_1']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
labels_enc = encoder.fit_transform(labels)

# %%
labels_enc
# Out:
# array([ 0,  0,  0, ..., 30, 30, 30], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(Embeddings,labels_enc,shuffle=True,random_state=12)

# %%
model.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', probability=True)

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.9973190348525469

# %%
y_train_pred = model.predict(X_train)
accuracy_score(y_train,y_train_pred)
# Out:
# 1.0

# %%
test = cv.imread('C:\\Users\\Satheesh\\Documents\\FRS\\8.jfif')
img = cv.cvtColor(test,cv.COLOR_BGR2RGB)
detector = MTCNN()
result = detector.detect_faces(img)
print(result)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step
# ...

# %%
x,y,w,h = result[0]['box']
img = img[y:y+h,x:x+w]
plt.imshow(img)

# %%
emd = get_embeddings(img)
print(emd)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026C47B03CE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# [-1.80999562e-02  1.06237102e-02  5.98193593e-02 -3.97199504e-02
#   4.96324971e-02  4.89533246e-02  3.12444996e-02 -6.06627262e-04
#  -2.52788514e-03 -2.48829927e-02 -3.87886651e-02 -2.65665669e-02
# ...

# %%
emd = np.asarray(emd).reshape(1,-1)


pred = model.predict(emd)
name = encoder.inverse_transform(pred)[0]
print(name)
# Out:
# Robert Downey Jr
